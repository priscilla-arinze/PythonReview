# %% [markdown]
# # Intro to NumPy

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Convert List to NumPy Array (1 Dimension)

# %%
l = [0, 1, 2, 3, 4]

a = np.array(l)
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
type(a)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Get Data Type of NumPy Array

# %%
a.dtype
# Out:
# dtype('int32')

# %% [markdown]
# ## Basic Operations

# %% [markdown]
# ### Array/Vector Addition
# ![image.png](attachment:image.png)

# %%
u = np.array([1, 0])
v = np.array([0, 1])

z = u + v
z
# Out:
# array([1, 1])

# %% [markdown]
# NOTE: `z = u + v` is the same as:
#
# ```python
# # this is slower than numpy addition
# for n, m in zip(u, v):
#     z.append(n + m)
# ```

# %% [markdown]
# #### Adding Constant To NumPy Array

# %%
x = np.array([1, 2, 3, -1])

z = x + 1
z
# Out:
# array([2, 3, 4, 0])

# %% [markdown]
# ### Vector Subtraction

# %%
z = u - v
z
# Out:
# array([ 1, -1])

# %% [markdown]
# ### Vector Multiplication

# %% [markdown]
# #### With a scalar

# %%
y = np.array([1, 2])
z = 2 * y

z
# Out:
# array([2, 4])

# %% [markdown]
# #### Product of 2 NumPy Arrays

# %%
u = np.array([1, 2])
v = np.array([3, 2])

z = u * v
z
# Out:
# array([3, 4])

# %% [markdown]
# #### Dot Product
# ![image.png](attachment:image.png)

# %%
u = np.array([1, 2])
v = np.array([3, 1])

z = np.dot(u, v)
z
# Out:
# 5

# %% [markdown]
# ## Aggregate Functions

# %% [markdown]
# ### Find Mean/Average of NumPy Array

# %%
a = np.array([5, -1, 1, 2])
mean_a = a.mean()
mean_a
# Out:
# 1.75

# %% [markdown]
# ### Max

# %%
a.max()
# Out:
# 5

# %% [markdown]
# ### Pi
# *first 15 digits*

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ### NumPy Array In Radians
# $x = [0, \dfrac\pi2 , \pi]$

# %%
x = np.array([0, np.pi/2, np.pi])
x
# Out:
# array([0.        , 1.57079633, 3.14159265])

# %% [markdown]
# ### Trigonometry
# ![image.png](attachment:image.png)

# %%
# applied sin function to EACH element in array: 0, pi/2, pi
y = np.sin(x)
y
# Out:
# array([0.0000000e+00, 1.0000000e+00, 1.2246468e-16])

# %% [markdown]
# ## Display Evenly Spaced Fractional Values Between 2 Numbers (based on given interval)

# %%
np.linspace(-2, 2, num=5)
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
np.linspace(-2, 2, num=9)
# Out:
# array([-2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ])

# %%
x = np.linspace(0, 2*np.pi, 100)
x
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
# ...

# %%
y = np.sin(x)
y
# Out:
# array([ 0.00000000e+00,  6.34239197e-02,  1.26592454e-01,  1.89251244e-01,
#         2.51147987e-01,  3.12033446e-01,  3.71662456e-01,  4.29794912e-01,
#         4.86196736e-01,  5.40640817e-01,  5.92907929e-01,  6.42787610e-01,
#         6.90079011e-01,  7.34591709e-01,  7.76146464e-01,  8.14575952e-01,
#         8.49725430e-01,  8.81453363e-01,  9.09631995e-01,  9.34147860e-01,
#         9.54902241e-01,  9.71811568e-01,  9.84807753e-01,  9.93838464e-01,
#         9.98867339e-01,  9.99874128e-01,  9.96854776e-01,  9.89821442e-01,
#         9.78802446e-01,  9.63842159e-01,  9.45000819e-01,  9.22354294e-01,
#         8.95993774e-01,  8.66025404e-01,  8.32569855e-01,  7.95761841e-01,
#         7.55749574e-01,  7.12694171e-01,  6.66769001e-01,  6.18158986e-01,
#         5.67059864e-01,  5.13677392e-01,  4.58226522e-01,  4.00930535e-01,
#         3.42020143e-01,  2.81732557e-01,  2.20310533e-01,  1.58001396e-01,
# ...

# %% [markdown]
# ## Plot Graph

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

plt.plot(x, y)

# %% [markdown]
# ## Two Dimensional Arrays

# %%
a = [ 
    [11, 12, 13],
    [21, 22, 23], 
    [31, 32, 33] 
]

# %% [markdown]
# ### Find number of dimensions in array

# %%
np.ndim(a)
# Out:
# 2

# %% [markdown]
# ### Access element in 2-D Array
#
# `arr[x][y]`
# * x - index of one of the multiple arrays
# * y - index of number in the x-index array

# %%
# 22
a[1][1]
# Out:
# 22
