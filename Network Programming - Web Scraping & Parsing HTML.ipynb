# %% [markdown]
# # Network Programming - Web Scraping & Parsing HTML
#
# Using BeautifulSoup

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

# %%
## For websites with expired SSL certificates:
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

## User input for URL
url = input('Enter URL: ') # Must be the full url (including the http part); e.g. https://simple.wikipedia.org/wiki/Nathan_MacKinnon

## Open & read web page contents of above URL
html = urllib.request.urlopen(url).read()

## Parse HTML with BeatifulSoup
soup = BeautifulSoup(html, 'html.parser')

## Find all anchor <a> tags & print its href URL
tags = soup('a')

for tag in tags:
    print(tag.get('href', None)) # get the href url only from a tags
# Out:
# None
# #mw-head
# #searchInput
# /wiki/File:Nathan_MacKinnon_playing_with_the_Avalanche_in_2020_(Quintin_Soloviev).jpg
# /w/index.php?title=Springhill,_Nova_Scotia&action=edit&redlink=1
# /wiki/Centre_(ice_hockey)
# /wiki/Shot_(ice_hockey)
# /wiki/National_Hockey_League
# /wiki/Colorado_Avalanche
# /wiki/Canada_men%27s_national_ice_hockey_team
# /wiki/NHL_Entry_Draft
# /w/index.php?title=2013_NHL_Entry_Draft&action=edit&redlink=1
# /wiki/Colorado_Avalanche
# /wiki/September_1
# /wiki/1995
# /wiki/Canadians
# /wiki/Ice_hockey
# /wiki/Centre_(ice_hockey)
# /wiki/Colorado_Avalanche
# /wiki/National_Hockey_League
# /wiki/Colorado_Avalanche
# /w/index.php?title=Nathan_MacKinnon&veaction=edit&section=1
# /w/index.php?title=Nathan_MacKinnon&action=edit&section=1
# #cite_note-nextnextone-1
# /wiki/Baie-Comeau_Drakkar
# #cite_note-2
# /wiki/Halifax_Mooseheads
# #cite_note-3
# /wiki/Memorial_Cup
# /wiki/Portland_Winterhawks
# #cite_note-4
# /wiki/Colorado_Avalanche
# #cite_note-5
# #cite_note-6
# /w/index.php?title=Nathan_MacKinnon&veaction=edit&section=2
# /w/index.php?title=Nathan_MacKinnon&action=edit&section=2
# #cite_ref-nextnextone_1-0
# http://www.torontosun.com/sports/hockey/2011/01/02/16737616.html
# /wiki/Toronto_Sun
# #cite_ref-2
# http://www.nhl.com/ice/news.htm?id=564819
# #cite_ref-3
# https://web.archive.org/web/20131006092923/http://www.tsn.ca/chl/story/?id=371647
# /wiki/The_Sports_Network
# https://www.tsn.ca/chl/story/?id=371647
# #cite_ref-4
# http://www.whl.ca/article/mooseheads-win-mastercard-memorial-cup
# #cite_ref-5
# http://www.nhl.com/ice/news.htm?id=675806
# #cite_ref-6
# http://www.nhl.com/ice/news.htm?id=677321
# /w/index.php?title=Nathan_MacKinnon&veaction=edit&section=3
# /w/index.php?title=Nathan_MacKinnon&action=edit&section=3
# https://www.nhl.com/player/8477492
# https://www.nhl.com
# http://www.hockeydb.com/ihdb/stats/pdisplay.php?pid=143744
# http://www.hockeydb.com/
# /w/index.php?title=Nail_Yakupov&action=edit&redlink=1
# /w/index.php?title=List_of_first_overall_NHL_draft_picks&action=edit&redlink=1
# /w/index.php?title=2013_NHL_Entry_Draft&action=edit&redlink=1
# /wiki/Aaron_Ekblad
# /w/index.php?title=Duncan_Siemens&action=edit&redlink=1
# /w/index.php?title=List_of_Colorado_Avalanche_draft_picks&action=edit&redlink=1
# /w/index.php?title=2013_NHL_Entry_Draft&action=edit&redlink=1
# /w/index.php?title=Conner_Bleackley&action=edit&redlink=1
# /w/index.php?title=Jonathan_Huberdeau&action=edit&redlink=1
# /wiki/Calder_Memorial_Trophy
# /wiki/2013%E2%80%9314_NHL_season
# /wiki/Aaron_Ekblad
# /wiki/File:Sports_icon.png
# /wiki/Wikipedia:Stub
# /wiki/Category:Sportspeople_stubs
# https://simple.wikipedia.org/w/index.php?title=Nathan_MacKinnon&action=edit
# /wiki/File:Flag_of_Canada.svg
# /wiki/Wikipedia:Stub
# /wiki/Category:Canada_stubs
# https://simple.wikipedia.org/w/index.php?title=Nathan_MacKinnon&action=edit
# https://simple.wikipedia.org/w/index.php?title=Nathan_MacKinnon&oldid=8064706
# /wiki/Special:Categories
# /wiki/Category:1995_births
# /wiki/Category:Calder_Trophy_winners
# /wiki/Category:Canadian_ice_hockey_centres
# /wiki/Category:Colorado_Avalanche_players
# /wiki/Category:Ice_hockey_people_from_Nova_Scotia
# /wiki/Category:Living_people
# /wiki/Category:People_from_Nova_Scotia
# /wiki/Category:Quebec_Major_Junior_Hockey_League_players
# /wiki/Category:Memorial_Cup_winners
# /wiki/Category:Sportspeople_stubs
# /wiki/Category:Canada_stubs
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Nathan+MacKinnon
# /w/index.php?title=Special:UserLogin&returnto=Nathan+MacKinnon
# /wiki/Nathan_MacKinnon
# /w/index.php?title=Talk:Nathan_MacKinnon&action=edit&redlink=1
# /wiki/Nathan_MacKinnon
# /w/index.php?title=Nathan_MacKinnon&veaction=edit
# /w/index.php?title=Nathan_MacKinnon&action=edit
# /w/index.php?title=Nathan_MacKinnon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Simple_start
# /wiki/Wikipedia:Simple_talk
# /wiki/Special:RecentChanges
# /wiki/Special:Random
# /wiki/Help:Contents
# //simple.wikipedia.org/wiki/Wikipedia:Contact_us
# //donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_simple.wikipedia.org&uselang=en
# /wiki/Wikipedia:About
# /wiki/Special:WhatLinksHere/Nathan_MacKinnon
# /wiki/Special:RecentChangesLinked/Nathan_MacKinnon
# //commons.wikimedia.org/wiki/Special:UploadWizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Nathan_MacKinnon&oldid=8064706
# /w/index.php?title=Nathan_MacKinnon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Nathan_MacKinnon&id=8064706&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q1966594
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=Nathan+MacKinnon
# /w/index.php?title=Special:DownloadAsPdf&page=Nathan_MacKinnon&action=show-download-screen
# /w/index.php?title=Nathan_MacKinnon&printable=yes
# https://commons.wikimedia.org/wiki/Category:Nathan_MacKinnon
# https://cs.wikipedia.org/wiki/Nathan_MacKinnon
# https://de.wikipedia.org/wiki/Nathan_MacKinnon
# https://et.wikipedia.org/wiki/Nathan_MacKinnon
# https://en.wikipedia.org/wiki/Nathan_MacKinnon
# https://es.wikipedia.org/wiki/Nathan_MacKinnon
# https://fr.wikipedia.org/wiki/Nathan_MacKinnon
# https://it.wikipedia.org/wiki/Nathan_MacKinnon
# https://lv.wikipedia.org/wiki/Neitans_Makinnons
# https://arz.wikipedia.org/wiki/%D9%86%D8%A7%D8%AB%D8%A7%D9%86_%D9%85%D8%A7%D9%83%D9%8A%D9%86%D9%88%D9%86
# https://no.wikipedia.org/wiki/Nathan_MacKinnon
# https://pl.wikipedia.org/wiki/Nathan_MacKinnon
# https://ru.wikipedia.org/wiki/%D0%9C%D0%B0%D0%BA%D0%BA%D0%B8%D0%BD%D0%BD%D0%BE%D0%BD,_%D0%9D%D0%B0%D1%82%D0%B0%D0%BD
# https://sk.wikipedia.org/wiki/Nathan_MacKinnon
# https://sr.wikipedia.org/wiki/%D0%9D%D0%B5%D1%98%D1%82%D0%B0%D0%BD_%D0%9C%D0%B0%D0%BA%D0%B8%D0%BD%D0%BE%D0%BD
# https://fi.wikipedia.org/wiki/Nathan_MacKinnon
# https://sv.wikipedia.org/wiki/Nathan_MacKinnon
# https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%82%D0%B0%D0%BD_%D0%9C%D0%B0%D0%BA-%D0%9A%D1%96%D0%BD%D0%BD%D0%BE%D0%BD
# https://www.wikidata.org/wiki/Special:EntityPage/Q1966594#sitelinks-wikipedia
# //simple.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //simple.wikipedia.org/wiki/Wikipedia:Text_of_the_GNU_Free_Documentation_License
# //wikimediafoundation.org/wiki/Terms_of_Use
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //simple.m.wikipedia.org/w/index.php?title=Nathan_MacKinnon&mobileaction=toggle_view_mobile
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/simple.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/
