# %% [markdown]
# # Data Visualization
#
# __Data Mining Technologies (great for large-scale data analysis projects)__:
# * [Apache Hadoop](https://hadoop.apache.org/)
# * [Apache Spark](https://spark.apache.org/)
# * [(AWS) Amazon Redshift](https://aws.amazon.com/redshift/)
# * [Hitachi Pentaho](https://www.hitachivantara.com/en-us/products/lumada-dataops/data-integration-analytics/download-pentaho.html)
#
# This tutorial will just use personal data mining techniques

# %% [markdown]
# <hr>

# %% [markdown]
# ### See Custom Data Visualization Project: __[Google Maps API - Texas Community Colleges](https://github.com/priscilla-arinze/Google-Maps-API---Texas-Community-Colleges)__

# %% [markdown]
# ### See Lecture Data Visualization Project: __[Page Rank](https://github.com/csev/py4e/tree/master/code3/pagerank)__
# * [Video Reference](https://www.youtube.com/watch?v=8DvywoWv6fI&t=6692s) (12:01:00 - 12:44:00)
# * *Description: Crawling multiple web pages on one website & shows a numerical "rank" for each page (in other words, # of times the web page is linked on other web pages, relative to all web pages on website) <br> Stores data in SQLite database, writes data to Javascript file in a JSON format, & visualizes data using [d3.js](https://d3js.org/)*

# %%
# Page Rank

from IPython.display import Image
from IPython.core.display import HTML 
Image(filename="../aa_Screenshots/pagerank.png", width=800)
