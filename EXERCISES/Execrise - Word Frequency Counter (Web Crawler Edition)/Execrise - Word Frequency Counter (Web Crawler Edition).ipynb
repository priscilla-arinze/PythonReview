# %% [markdown]
# # Exercise - Word Frequency Counter (Web Crawler Edition)
#
# *Based on `PythonReview\EXERCISES\Exercise - How to Build A Web Crawler`*

# %% [markdown]
# ## Objective: Crawling [Indeed.com](https://www.indeed.com) for most common words in software developer job descriptions in Dallas, TX
# Starting URL: https://www.indeed.com/jobs?q=software%20developer&l=Dallas,%20TX&start=0  *(start=# goes up by increments of 10)*

# %% [markdown]
# *Note: Too many manual web scraping requests, especially requests sent one after another, may result in getting blocked by web server.*
#
# Workarounds after getting blocked:
# * clear cookies/cache on Indeed from web browser
# * Command Prompt >> `ipconfig /release` >> ENTER `ipconfig /renew` >> ENTER (to get assigned a new IP address with DHCP)
# * try to do it with a VPN and/or proxy
# * make sure to include the below header info (see `get_job_posting_links` function)
#
# __And with any of the above workarounds, make sure to NOT send too many requests or will get blocked again. Wait a few minutes before sending another request.__

# %% [markdown]
# ### Expanded Project Idea (separate repository): Find out the most common programming languages out of all job descriptions using a separate list of all lowercase programming languages

# %%
import requests # one of the ways to connect to websites via Python
from bs4 import BeautifulSoup # allows you to go through page source and get data
import operator # will help with counting words

# %% [markdown]
# - - - -

# %% [markdown]
# ### Dynamic Web Crawler

# %%
# set max pages
def get_job_posting_links(max_pages):
    page = 0  # increment by 10
    website_links = list()
    word_list = list()

    while page <= max_pages:
         

        url = "https://www.indeed.com/jobs?q=software%20developer&l=Dallas,%20TX&start="+str(page)
        
        # Avoid getting blocked in case multiple requests are sent
        header = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:101.0) Gecko/20100101 Firefox/101.0",
            'referer':'https://www.indeed.com/'
        }

        proxy = {'http': 'http://12.231.44.251:3128'}

        # GET request; stores page HTML source in variable
        source_code = requests.get(url, headers=header, proxies=proxy) 

        # gets the front end text of the HTMl source code; ignoring back end stuff; essentally parses through HTML source
        plain_text = source_code.text 

        # can sort through this variable
        soup = BeautifulSoup(plain_text) 

        
        # Searched through all of the job posting links & added them to website_links list ( inspect element for unique class/id names)
        for link in soup.findAll('a', {'class': 'jcs-JobTitle'}): # similar to CSS descendant selectors (a .jcs-JobTitle)
            job_href = "https://www.indeed.com" + link.get('href')
            website_links.append(job_href)
        

        
        

        # Execute below function for each link in website_links list
        for index in website_links:

            return_list = indiv_job_posting_info(index) # store urls of each job listing meant for function in below cell
            
            for index2 in return_list:
                word_list.append(index2)

        # Increment pages by 10
        page += 10


        word_list_cleaned = clean_up_list(word_list)
        wordfrequency(word_list_cleaned)

# %%
def indiv_job_posting_info(job_url):
        
        word_list_temp = list()

        # GET request; stores page HTML source in variable
        source_code = requests.get(job_url) 

        # gets the front end text of the HTMl source code; ignoring back end stuff; essentally parses through HTML source
        plain_text = source_code.text 

        # can sort through this variable
        soup = BeautifulSoup(plain_text)
        
        # find the job description
        jobdesc = soup.find('div', {'id': 'jobDescriptionText'})
        
        # remove all the HTML tags from the job description & split job description by each word; stored in a list
        job_desc_list = jobdesc.get_text().lower().split() # all lowercase
                
        
        return job_desc_list

# %%
# removed extra unnecessary symbols
def clean_up_list(word_ls):
    clean_word_list = []

    for word in word_ls:
        symbols_to_remove = '".&:,\'()$1234567890'

        for index in range(0, len(symbols_to_remove)):
            word = word.replace(symbols_to_remove[index], "")

        if len(word) > 0:
            clean_word_list.append(word)   

    return clean_word_list

# %%
def wordfrequency(word_ls):
    counts = dict()


    for word in word_ls:
        counts[word] = counts.get(word, 0) + 1

    ## SORTING DICTIONARY (using operator module)
    for key, val in sorted(counts.items(), key=operator.itemgetter(1), reverse=True): # 0 for key, 1 for value
        print(key, "---", val)

# %% [markdown]
# ### MOST COMMON WORDS:

# %%
get_job_posting_links(0)
# Out:
# and --- 206
# to --- 157
# the --- 125
# of --- 82
# with --- 74
# a --- 72
# in --- 67
# software --- 51
# work --- 46
# or --- 46
# on --- 44
# we --- 42
# experience --- 42
# for --- 41
# you --- 39
# are --- 36
# is --- 35
# your --- 32
# will --- 31
# our --- 30
# ability --- 27
# as --- 26
# preferred --- 25
# insurance --- 24
# skills --- 24
# an --- 23
# job --- 22
# one --- 21
# - --- 21
# at --- 21
# team --- 21
# development --- 20
# location --- 20
# have --- 17
# us --- 17
# developer --- 16
# design --- 16
# year --- 16
# that --- 16
# all --- 15
# from --- 15
# technology --- 15
# training --- 15
# requirements --- 14
# not --- 14
# benefits --- 14
# opportunity --- 14
# learn --- 13
# systems --- 13
# information --- 13
# pay --- 13
# time --- 13
# engineering --- 13
# engineer --- 13
# develop --- 13
# be --- 12
# full-time --- 12
# assistance --- 12
# this --- 12
# knowledge --- 11
# responsibilities --- 11
# required --- 11
# per --- 11
# computer --- 11
# other --- 10
# technical --- 10
# program --- 10
# schedule --- 10
# health --- 10
# paid --- 10
# java --- 10
# their --- 10
# career --- 10
# relocation --- 10
# strong --- 10
# more --- 10
# employment --- 10
# any --- 10
# teams --- 10
# hour --- 10
# applications --- 10
# company --- 9
# but --- 9
# k --- 9
# building --- 9
# looking --- 9
# status --- 9
# data --- 8
# working --- 8
# new --- 8
# environment --- 8
# code --- 8
# web --- 8
# technologies --- 8
# dental --- 8
# life --- 8
# build --- 8
# services --- 8
# management --- 8
# science --- 8
# degree --- 8
# revature --- 8
# tech --- 8
# provide --- 8
# equal --- 8
# applicable --- 8
# candidates --- 8
# business --- 8
# shift --- 8
# conversation --- 8
# ic --- 8
# best --- 7
# years --- 7
# well --- 7
# good --- 7
# programming --- 7
# microsoft --- 7
# type --- 7
# off --- 7
# vision --- 7
# products --- 7
# service --- 7
# familiarity --- 7
# test --- 7
# across --- 7
# level --- 7
# starting --- 7
# engineers --- 7
# salary --- 7
# – --- 7
# bachelors --- 7
# must --- 7
# disability --- 7
# protected --- 7
# hiring --- 7
# accommodation --- 7
# by --- 7
# project --- 7
# make --- 7
# tx --- 7
# deliver --- 7
# solutions --- 7
# appian --- 7
# position --- 6
# coding --- 6
# user --- 6
# languages --- 6
# support --- 6
# meetings --- 6
# employee --- 6
# education --- 6
# no --- 6
# employer --- 6
# competitive --- 6
# companies --- 6
# willing --- 6
# relocate --- 6
# laws --- 6
# policy --- 6
# applicants --- 6
# open --- 6
# / --- 6
# role --- 6
# many --- 6
# chat --- 6
# about --- 5
# write --- 5
# limited --- 5
# flexible --- 5
# who --- 5
# platform --- 5
# within --- 5
# planning --- 5
# + --- 5
# professional --- 5
# entry --- 5
# right --- 5
# you’ll --- 5
# college --- 5
# associates --- 5
# federal --- 5
# state --- 5
# local --- 5
# including --- 5
# based --- 5
# these --- 5
# day --- 5
# where --- 5
# apply --- 5
# providing --- 5
# it --- 5
# do --- 5
# include --- 5
# dallas --- 5
# amazon --- 5
# opportunities --- 5
# reactjs --- 5
# python --- 5
# users --- 5
# marketscout --- 4
# seeking --- 4
# junior --- 4
# learning --- 4
# writing --- 4
# functionality --- 4
# such --- 4
# account --- 4
# features --- 4
# existing --- 4
# also --- 4
# product --- 4
# specifications --- 4
# tools --- 4
# testing --- 4
# qualifications --- 4
# following --- 4
# using --- 4
# able --- 4
# stack --- 4
# prior --- 4
# industry --- 4
# projects --- 4
# get --- 4
# placement --- 4
# partners --- 4
# wide --- 4
# can --- 4
# desire --- 4
# communication --- 4
# anywhere --- 4
# own --- 4
# without --- 4
# regard --- 4
# race --- 4
# religion --- 4
# color --- 4
# sex --- 4
# related --- 4
# medical --- 4
# conditions --- 4
# national --- 4
# origin --- 4
# age --- 4
# marital --- 4
# if --- 4
# request --- 4
# company’s --- 4
# fortune --- 4
# through --- 4
# offer --- 4
# relevant --- 4
# meet --- 4
# ideal --- 4
# c++ --- 4
# fit --- 4
# during --- 4
# commute/relocate --- 4
# reliably --- 4
# commute --- 4
# before --- 4
# customers --- 4
# highly --- 4
# match --- 4
# scale --- 4
# passionate --- 4
# security --- 4
# skillstorm --- 4
# maintain --- 4
# communicate --- 4
# levels --- 4
# high-quality --- 4
# richardson --- 4
# intelligent --- 4
# power --- 4
# real-time --- 4
# calling --- 4
# every --- 4
# conversations --- 4
# better --- 4
# sewell --- 4
# over --- 3
# has --- 3
# join --- 3
# requests --- 3
# ensure --- 3
# success --- 3
# should --- 3
# basic --- 3
# ultimately --- 3
# performance --- 3
# office --- 3
# referral --- 3
# reimbursement --- 3
# monday --- 3
# friday --- 3
# latest --- 3
# improve --- 3
# components --- 3
# next --- 3
# multiple --- 3
# efficiency --- 3
# aws --- 3
# cloud --- 3
# application --- 3
# delivery --- 3
# launch --- 3
# hands --- 3
# great --- 3
# understanding --- 3
# sets --- 3
# need --- 3
# full --- 3
# ui --- 3
# individuals --- 3
# largest --- 3
# talent --- 3
# receive --- 3
# experienced --- 3
# certifications --- 3
# promotion --- 3
# most --- 3
# we’re --- 3
# range --- 3
# what --- 3
# authorized --- 3
# problem --- 3
# player --- 3
# into --- 3
# put --- 3
# pregnancy --- 3
# sexual --- 3
# orientation --- 3
# gender --- 3
# identity --- 3
# genetic --- 3
# veteran --- 3
# under --- 3
# compensation --- 3
# please --- 3
# evaluate --- 3
# comply --- 3
# commitment --- 3
# practices --- 3
# clients --- 3
# create --- 3
# others --- 3
# some --- 3
# net --- 3
# communications --- 3
# out --- 3
# available --- 3
# been --- 3
# core --- 3
# weeks --- 3
# client --- 3
# hire --- 3
# plus --- 3
# leave --- 3
# experiences --- 3
# impact --- 3
# millions --- 3
# making --- 3
# allow --- 3
# scalable --- 3
# united --- 3
# states --- 3
# video --- 3
# consumer --- 3
# just --- 3
# front-end --- 3
# ci/cd --- 3
# diverse --- 3
# capabilities --- 3
# they --- 3
# running --- 3
# and/or --- 3
# deploy --- 3
# results --- 3
# enterprise --- 3
# mission --- 3
# train --- 3
# reliable --- 3
# critical --- 3
# fully --- 3
# positive --- 3
# help --- 3
# various --- 3
# programs --- 3
# third-party --- 3
# like --- 3
# document --- 3
# overview --- 3
# each --- 3
# automotive --- 3
# sql --- 3
# system --- 3
# creative --- 2
# past --- 2
# online --- 2
# manager --- 2
# assist --- 2
# codebase --- 2
# gather --- 2
# respond --- 2
# senior --- 2
# quickly --- 2
# improving --- 2
# internal --- 2
# tests --- 2
# minimum --- 2
# javascript --- 2
# mysql --- 2
# databases --- 2
# discount --- 2
# spending --- 2
# savings --- 2
# tuition --- 2
# group --- 2
# love --- 2
# ecommerce --- 2
# high --- 2
# agile --- 2
# accuracy --- 2
# specialized --- 2
# search --- 2
# junit --- 2
# patterns --- 2
# lists --- 2
# familiar --- 2
# trees --- 2
# algorithms --- 2
# solve --- 2
# problems --- 2
# big --- 2
# android --- 2
# previous --- 2
# additional --- 2
# talented --- 2
# motivated --- 2
# fastest --- 2
# growing --- 2
# emerging --- 2
# come --- 2
# remote --- 2
# interviews --- 2
# housing --- 2
# mentoring --- 2
# % --- 2
# after --- 2
# world --- 2
# corporate --- 2
# in-demand --- 2
# together --- 2
# vital --- 2
# organization --- 2
# collaborate --- 2
# natural --- 2
# solver --- 2
# interpersonal --- 2
# provided --- 2
# than --- 2
# track --- 2
# extend --- 2
# childbirth --- 2
# applies --- 2
# terms --- 2
# termination --- 2
# layoff --- 2
# recall --- 2
# transfer --- 2
# leaves --- 2
# absence --- 2
# require --- 2
# factors --- 2
# notify --- 2
# human --- 2
# resources --- 2
# department --- 2
# accordance --- 2
# law --- 2
# seek --- 2
# discrimination --- 2
# tolerate --- 2
# interference --- 2
# employees --- 2
# perform --- 2
# duties --- 2
# reflects --- 2
# affirms --- 2
# principles --- 2
# fair --- 2
# elimination --- 2
# discriminatory --- 2
# someone --- 2
# going --- 2
# government --- 2
# organizations --- 2
# top --- 2
# only --- 2
# give --- 2
# ongoing --- 2
# today --- 2
# now --- 2
# execute --- 2
# alm --- 2
# jira --- 2
# modify --- 2
# written --- 2
# potential --- 2
# deadlines --- 2
# processes --- 2
# backgrounds --- 2
# networking --- 2
# finance --- 2
# operations --- 2
# bonus --- 2
# visa --- 2
# sponsorship --- 2
# workforce --- 2
# months --- 2
# graduates --- 2
# encouraged --- 2
# free --- 2
# classroom --- 2
# apolis --- 2
# efficient --- 2
# attention --- 2
# hours --- 2
# high-demand --- 2
# types --- 2
# contract --- 2
# needs --- 2
# people --- 2
# committed --- 2
# creating --- 2
# offers --- 2
# options --- 2
# harmony --- 2
# complex --- 2
# developing --- 2
# ready --- 2
# matched --- 2
# roles --- 2
# preferences --- 2
# managers --- 2
# legal --- 2
# depending --- 2
# expertise --- 2
# back-end --- 2
# customer --- 2
# delivering --- 2
# model --- 2
# analysis --- 2
# operational --- 2
# stakeholders --- 2
# matching --- 2
# always --- 2
# folks --- 2
# via --- 2
# apis --- 2
# certification --- 2
# eoe --- 2
# certified --- 2
# associate --- 2
# careers --- 2
# stormers --- 2
# us-based --- 2
# clearance --- 2
# client’s --- 2
# jr --- 2
# duration --- 2
# css --- 2
# integrate --- 2
# debug --- 2
# prioritize --- 2
# least --- 2
# popular --- 2
# framework --- 2
# orm --- 2
# problem-solving --- 2
# proven --- 2
# designing --- 2
# interactive --- 2
# test-driven --- 2
# proficiency --- 2
# bsc --- 2
# field --- 2
# microsoft’s --- 2
# first-party --- 2
# notably --- 2
# skype --- 2
# audio --- 2
# device --- 2
# expose --- 2
# which --- 2
# bring --- 2
# enable --- 2
# surfacing --- 2
# useful --- 2
# taking --- 2
# actions --- 2
# customers’ --- 2
# behalf --- 2
# call --- 2
# meeting --- 2
# hundreds --- 2
# million --- 2
# very --- 2
# challenging --- 2
# lot --- 2
# fun --- 2
# rewarding --- 2
# smart --- 2
# broad --- 2
# domains --- 2
# audio/video --- 2
# want --- 2
# because --- 2
# insatiable --- 2
# passion --- 2
# constant --- 2
# intellectual --- 2
# curiosity --- 2
# willingness --- 2
# contributions --- 2
# course --- 2
# c# --- 2
# qualified --- 2
# process --- 2
# first --- 2
# land --- 2
# functional --- 2
# queries --- 2
# skill --- 2
# personalities --- 2
# -ability --- 2
# effectively --- 2
# cycle --- 2
# sdlc --- 2
# standards --- 2
# plans --- 2
# progressive --- 1
# focusing --- 1
# innovation --- 1
# concepts --- 1
# financial --- 1
# industries --- 1
# named --- 1
# places --- 1
# nine --- 1
# consecutive --- 1
# owns --- 1
# operates --- 1
# exchange --- 1
# wwwmarketscoutcom --- 1
# traditional --- 1
# underwriting --- 1
# distribution --- 1
# venues --- 1
# offices --- 1
# alabama --- 1
# arkansas --- 1
# florida --- 1
# illinois --- 1
# nebraska --- 1
# pennsylvania --- 1
# south --- 1
# carolina --- 1
# tennessee --- 1
# texas --- 1
# washington --- 1
# dc --- 1
# summary --- 1
# enthusiastic --- 1
# report --- 1
# directly --- 1
# functions --- 1
# primary --- 1
# focus --- 1
# developers --- 1
# top-class --- 1
# provides --- 1
# valuable --- 1
# while --- 1
# continually --- 1
# aspects --- 1
# attend --- 1
# contribute --- 1
# maintaining --- 1
# minor --- 1
# bug --- 1
# fixes --- 1
# monitor --- 1
# consumers --- 1
# mckinney --- 1
# houston --- 1
# austin --- 1
# san --- 1
# antonio --- 1
# sugar --- 1
# brands --- 1
# audi --- 1
# bmw --- 1
# buick --- 1
# cadillac --- 1
# gmc --- 1
# infiniti --- 1
# jaguar --- 1
# rover --- 1
# lexus --- 1
# mercedes-benz --- 1
# mini --- 1
# subaru --- 1
# -design --- 1
# user-friendly --- 1
# -review --- 1
# enhance --- 1
# mobile --- 1
# desktop-based --- 1
# -work --- 1
# retrieve --- 1
# warehouse --- 1
# -support --- 1
# developed --- 1
# tools/applications --- 1
# -software --- 1
# microsoftnet --- 1
# vbnet --- 1
# -html --- 1
# javascript/jquery --- 1
# -experience --- 1
# consuming --- 1
# -sql --- 1
# ideally --- 1
# -critical --- 1
# thinking --- 1
# analytical --- 1
# workload --- 1
# consistently --- 1
# both --- 1
# orally --- 1
# -strong --- 1
# dealing --- 1
# -customer --- 1
# mindset --- 1
# -competitive --- 1
# -continuous --- 1
# -world-class --- 1
# -medical --- 1
# -tuition --- 1
# qualifying --- 1
# -company --- 1
# short-term --- 1
# -life --- 1
# long-term --- 1
# maintains --- 1
# promote --- 1
# compensate --- 1
# basis --- 1
# personal --- 1
# competence --- 1
# advancement --- 1
# citizenship --- 1
# classifications --- 1
# note --- 1
# several --- 1
# facilities --- 1
# located --- 1
# nation --- 1
# install --- 1
# gathering --- 1
# defining --- 1
# eg --- 1
# jscriptnet --- 1
# preliminary --- 1
# deployment --- 1
# innovative --- 1
# performing --- 1
# complies --- 1
# well-designed --- 1
# testable --- 1
# produce --- 1
# determine --- 1
# feasibility --- 1
# verification --- 1
# quality --- 1
# assurance --- 1
# procedures --- 1
# troubleshoot --- 1
# upgrade --- 1
# feedback --- 1
# updated --- 1
# relational --- 1
# jpa --- 1
# hibernate --- 1
# jsf --- 1
# wicket --- 1
# gwt --- 1
# spring --- 1
# mvc --- 1
# rest --- 1
# locations --- 1

# %% [markdown]
# ### FULL LIST OF KEYWORDS:

# %%
# FULL LIST

get_job_posting_links(0)
# Out:
# ['marketscout', 'is', 'a', 'progressive', 'company', 'focusing', 'on', 'innovation', 'and', 'creative', 'concepts', 'in', 'the', 'insurance', 'and', 'financial', 'industries.', 'marketscout,', 'named', 'one', 'of', 'the', 'best', 'places', 'to', 'work', 'in', 'insurance', 'for', 'the', 'past', 'nine', 'consecutive', 'years', '(2012', '-', '2021),', 'owns', 'and', 'operates', 'the', 'marketscout', 'exchange', 'at', 'www.marketscout.com,', 'as', 'well', 'as', 'over', '40', 'other', 'online', 'and', 'traditional', 'underwriting', 'and', 'distribution', 'venues.', 'marketscout', 'has', 'offices', 'in', 'alabama,', 'arkansas,', 'florida,', 'illinois,', 'nebraska,', 'pennsylvania,', 'south', 'carolina,', 'tennessee,', 'texas,', 'and', 'washington,', 'dc.', 'position', 'summary:', 'we', 'are', 'seeking', 'an', 'enthusiastic', 'junior', 'software', 'developer', 'to', 'join', 'our', 'software', 'design', 'team.', 'you', 'will', 'report', 'directly', 'to', 'the', 'development', 'manager', 'and', 'assist', 'with', 'all', 'functions', 'of', 'software', 'coding', 'and', 'design.', 'your', 'primary', 'focus', 'will', 'be', 'to', 'learn', 'the', 'codebase,', 'gather', 'user', 'data,', 'and', 'respond', 'to', 'requests', 'from', 'senior', 'developers.', 'to', 'ensure', 'success', 'as', 'a', 'junior', 'software', 'developer,', 'you', 'should', 'have', 'a', 'good', 'working', 'knowledge', 'of', 'basic', 'programming', 'languages,', 'the', 'ability', 'to', 'learn', 'new', 'technology', 'quickly,', 'and', 'the', 'ability', 'to', 'work', 'in', 'a', 'team', 'environment.', 'ultimately,', 'a', 'top-class', 'junior', 'software', 'developer', 'provides', 'valuable', 'support', 'to', 'the', 'design', 'team', 'while', 'continually', 'improving', 'your', 'coding', 'and', 'design', 'skills.', 'responsibilities:', 'assist', 'the', 'development', 'manager', 'with', 'all', 'aspects', 'of', 'software', 'design', 'and', 'coding', 'attend', 'and', 'contribute', 'to', 'company', 'development', 'meetings', 'learning', 'the', 'codebase', 'and', 'improving', 'your', 'coding', 'skills', 'writing', 'and', 'maintaining', 'code', 'work', 'on', 'minor', 'bug', 'fixes', 'monitor', 'the', 'technical', 'performance', 'of', 'internal', 'systems', 'respond', 'to', 'requests', 'from', 'the', 'development', 'team', 'gather', 'information', 'from', 'consumers', 'about', 'program', 'functionality', 'write', 'reports', 'conduct', 'development', 'tests', 'requirements:', 'minimum', '1', 'year', 'experience', 'required', 'knowledge', 'of', 'web', 'technologies', 'such', 'as', 'but', 'not', 'limited', 'to', 'php,', 'javascript,', 'mssql,', 'mysql', 'knowledge', 'of', 'databases', 'and', 'operating', 'systems', 'good', 'working', 'knowledge', 'of', 'email', 'systems', 'and', 'microsoft', 'office', 'software', 'ability', 'to', 'learn', 'new', 'software', 'and', 'technologies', 'quickly', 'ability', 'to', 'follow', 'instructions', 'and', 'work', 'in', 'a', 'team', 'environment', 'detail-oriented', 'job', 'type:', 'full-time', 'pay:', '$60,000.00', '-', '$70,000.00', 'per', 'year', 'benefits:', '401(k)', 'dental', 'insurance', 'employee', 'assistance', 'program', 'employee', 'discount', 'flexible', 'schedule', 'flexible', 'spending', 'account', 'health', 'insurance', 'health', 'savings', 'account', 'life', 'insurance', 'paid', 'time', 'off', 'referral', 'program', 'tuition', 'reimbursement', 'vision', 'insurance', 'schedule:', 'monday', 'to', 'friday', 'experience:', 'basic', 'programming:', '1', 'year', '(preferred)', 'work', 'location:', 'one', 'location', 'we', 'are', 'a', 'group', 'of', 'technologists', 'who', 'love', 'to', 'work', 'on', 'the', 'latest', 'technology', 'to', 'build', 'new', 'features', 'and', 'improve', 'existing', 'components', 'of', "disney's", 'ecommerce', 'platform', 'specializing', 'in', 'ticketing', 'products.', 'we', 'also', 'take', 'pride', 'in', 'building', 'the', 'next', 'generation', 'of', 'ecommerce', 'products', 'for', 'multiple', 'departments', 'within' ...
